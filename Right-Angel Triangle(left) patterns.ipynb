# %%
for i in range(1,6):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print(i,end = "")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
n = 5
for i in range(1,n+1):
    for j in range(1,i+1):
        print(j,end = "")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
for i,j in enumerate(range(ord('A')-1,ord('E')+1)):
    print(chr(j)*i)
# Out:
# A
# BB
# CCC
# DDDD
# EEEEE

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print(chr(64+j),end = "")
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE
